# %%
filepath = '~/Documents/RedRoot/csv/Attendee/NQC Ep 1 Attendee Report June 14, 2021 - 89855766134.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import mpld3
plt.rcParams['figure.dpi'] = 150
plt.style.use('ggplot')

defaultpie = {
    "autopct":"(%1.1f%%)",
    "pctdistance":0.8,
    "labeldistance":1.1,
    "rotatelabels":False,
    "textprops":{'fontsize':'xx-small'}
}

def get_count(key, df):
    return df.groupby(key)[key].count()

def shorten(s):
    if (s.startswith('Division')):
        i = s.index('(')
        return s[0:i]
    else:
        return s
    
def get_percent(counts):
    return np.array(list(map(lambda x: round(x / sum(counts),3)*100, counts)))

def get_table(s):
    return pd.DataFrame(np.vstack([s.values, get_percent(s.values)]).T,
                       columns=['Count', '%'], index=s.index)

# %%
df = pd.read_csv(filepath, index_col=False).drop_duplicates('Email')

# %%
attendance = get_count('Attended', df)
get_table(attendance)
# Out:
#           Count     %
# Attended
# No        361.0  39.7
# Yes       548.0  60.3

# %%
attendance.plot.pie(**defaultpie)
plt.show()

# %%
attendance.plot.bar()
plt.show()

# %%
region = get_count('Gender', df)
get_table(region)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-c35f91aa0fa6>", line 1, in <module>
#     region = get_count('Gender', df)
#   File "<ipython-input-2-218b9ca93d02>", line 18, in get_count
#     return df.groupby(key)[key].count()
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 6717, in groupby
#     return DataFrameGroupBy(
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py", line 560, in __init__
#     grouper, exclusions, obj = get_grouper(
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/grouper.py", line 811, in get_grouper
#     raise KeyError(gpr)
# KeyError: 'Gender'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/laurents/anaconda3/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/laurents/anaconda3/lib/python3.8/inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/laurents/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/laurents/anaconda3/lib/python3.8/inspect.py", line 737, in getmodule
#     file = getabsfile(object, _filename)
#   File "/home/laurents/anaconda3/lib/python3.8/inspect.py", line 721, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/laurents/anaconda3/lib/python3.8/posixpath.py", line 379, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 5] Input/output error
# Traceback (most recent call last):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-c35f91aa0fa6>", line 1, in <module>
#     region = get_count('Gender', df)
#   File "<ipython-input-2-218b9ca93d02>", line 18, in get_count
#     return df.groupby(key)[key].count()
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 6717, in groupby
#     return DataFrameGroupBy(
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py", line 560, in __init__
#     grouper, exclusions, obj = get_grouper(
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/grouper.py", line 811, in get_grouper
#     raise KeyError(gpr)
# KeyError: 'Gender'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3454, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2063, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/laurents/anaconda3/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/laurents/anaconda3/lib/python3.8/inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/laurents/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/laurents/anaconda3/lib/python3.8/inspect.py", line 737, in getmodule
#     file = getabsfile(object, _filename)
#   File "/home/laurents/anaconda3/lib/python3.8/inspect.py", line 721, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/laurents/anaconda3/lib/python3.8/posixpath.py", line 379, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 5] Input/output error
# Traceback (most recent call last):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-c35f91aa0fa6>", line 1, in <module>
#     region = get_count('Gender', df)
#   File "<ipython-input-2-218b9ca93d02>", line 18, in get_count
#     return df.groupby(key)[key].count()
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 6717, in groupby
#     return DataFrameGroupBy(
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py", line 560, in __init__
#     grouper, exclusions, obj = get_grouper(
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/grouper.py", line 811, in get_grouper
#     raise KeyError(gpr)
# KeyError: 'Gender'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3454, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2063, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3376, in run_ast_nodes
#     self.showtraceback()
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2063, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/laurents/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/laurents/anaconda3/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/laurents/anaconda3/lib/python3.8/inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/laurents/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/laurents/anaconda3/lib/python3.8/inspect.py", line 737, in getmodule
#     file = getabsfile(object, _filename)
#   File "/home/laurents/anaconda3/lib/python3.8/inspect.py", line 721, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/laurents/anaconda3/lib/python3.8/posixpath.py", line 379, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 5] Input/output error
